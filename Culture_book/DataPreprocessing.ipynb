# %%
import pandas as pd
import os
import warnings
import numpy as np

warnings.filterwarnings("ignore")

# %%
df_library_list = pd.read_csv("./DataSet_row/NL_CD_LIBRARY_202212.csv") # 서울시 공공도서관 list
df_library_list
# Out:
#       LBRRY_CD      LBRRY_NM               LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0         1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1         1501     포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2         1502     포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3         1503  포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4         1504     포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...        ...           ...                      ...        ...         ...
# 1492      2657       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493      2624     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      6704      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495     33600       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496     33601  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
# ...

# %%
df_library_list = df_library_list[df_library_list['ONE_AREA_NM']=='서울특별시']
df_library_list
# Out:
#       LBRRY_CD   LBRRY_NM                       LBRRY_ADDR   LBRRY_LA  \
# 63         100    성북정보도서관             서울특별시 성북구 화랑로18자길 13  37.604849
# 64         101     해오름도서관  서울특별시 성북구 성북로4길 52, 주차장 위 지상 2층  37.594177
# 65         102     아리랑도서관                서울특별시 성북구 아리랑로 82  37.599899
# 66         103  서경로꿈마루도서관               서울특별시 성북구 서경로 94-1  37.611463
# 67         104  석관동미리내도서관             서울특별시 성북구 한천로66길 203  37.613522
# ...        ...        ...                              ...        ...
# 1433     25934    공릉행복도서관             서울특별시 노원구 동일로179길 22  37.622310
# 1434     25909  한내지혜의숲도서관                 서울특별시 노원구 마들로 86  37.621734
# 1435     25931    향기나무도서관            서울특별시 노원구 노원로 331, 1층  37.646499
# 1436     27737     까망돌도서관                서울특별시 동작구 서달로 129  37.505058
# 1437     10414  마포소금나루도서관                 서울특별시 마포구 숭문길 72  37.549567
#
#         LBRRY_LO ONE_AREA_NM TWO_AREA_NM  LBRRY_NO  API_LBRRY_NO  \
# ...

# %%
df_library_list = df_library_list.set_index(["TWO_AREA_NM","LBRRY_NM"])
df_library_list
# Out:
#                        LBRRY_CD                       LBRRY_ADDR   LBRRY_LA  \
# TWO_AREA_NM LBRRY_NM
# 성북구         성북정보도서관         100             서울특별시 성북구 화랑로18자길 13  37.604849
#             해오름도서관          101  서울특별시 성북구 성북로4길 52, 주차장 위 지상 2층  37.594177
#             아리랑도서관          102                서울특별시 성북구 아리랑로 82  37.599899
#             서경로꿈마루도서관       103               서울특별시 성북구 서경로 94-1  37.611463
#             석관동미리내도서관       104             서울특별시 성북구 한천로66길 203  37.613522
# ...                         ...                              ...        ...
# 노원구         공릉행복도서관       25934             서울특별시 노원구 동일로179길 22  37.622310
#             한내지혜의숲도서관     25909                 서울특별시 노원구 마들로 86  37.621734
#             향기나무도서관       25931            서울특별시 노원구 노원로 331, 1층  37.646499
# 동작구         까망돌도서관        27737                서울특별시 동작구 서달로 129  37.505058
# 마포구         마포소금나루도서관     10414                 서울특별시 마포구 숭문길 72  37.549567
#
# ...

# %%
#df_library_list.to_csv("df_library_list.csv")

# %%
book_loan_1month = pd.DataFrame()
df1 = pd.read_csv(file_path1 + file_path2[0] + "/" + file_path3[0])
book_loan_1month = pd.concat([book_loan_1month, df1])
book_loan_1month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 book_loan_1month = pd.DataFrame()
# ----> 2 df1 = pd.read_csv(file_path1 + file_path2[0] + "/" + file_path3[0])
#       3 book_loan_1month = pd.concat([book_loan_1month, df1])
#       4 book_loan_1month
#
# NameError: name 'file_path1' is not defined

# %%
target_va = df_library_list['LBRRY_CD'].unique()
len(target_va)
# Out:
# 332

# %%
file_path1 = "./DataSet_row/2022_loan_montly/"
file_path2 = os.listdir("./DataSet_row/2022_loan_montly/")
file_path3 = os.listdir('./DataSet_row/2022_loan_montly/' + file_path2[0])
file_path1 + file_path2[0] + "/" + file_path3[0]
# Out:
# './DataSet_row/2022_loan_montly/month_1/NL_CO_LOAN_PUB_202201-1.csv'

# %%
for name1 in file_path2:
    df_1 = pd.DataFrame()
    print(name1)
    for name2 in os.listdir("./DataSet_row/2022_loan_montly/"+name1):
        df_2 = pd.read_csv(file_path1 + name1 + "/" + name2)
        df_2 = df_2[df_2['LBRRY_CD'].isin(target_va)]
        df_1 = df_1.append(df_2)
    
    df_1.to_csv(name1 + ".csv")
# Out:
# month_1
# month_2
# month_3
# month_4
# month_5
# month_6

# %%
from sqlalchemy import create_engine

user = 'root'
password = 'rkrmfls12!'
host = 'localhost'
port = 3306
database = 'culture_book'

engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}?charset=utf8mb4')

# %%
df_library_list = df_library_list.reset_index()
df_library_list = df_library_list[['TWO_AREA_NM', 'LBRRY_NM', 'LBRRY_CD', 'LBRRY_LA', 'LBRRY_LO']]
df_library_list
# Out:
#     TWO_AREA_NM   LBRRY_NM  LBRRY_CD   LBRRY_LA    LBRRY_LO
# 0           성북구    성북정보도서관       100  37.604849  127.050425
# 1           성북구     해오름도서관       101  37.594177  127.010608
# 2           성북구     아리랑도서관       102  37.599899  127.013975
# 3           성북구  서경로꿈마루도서관       103  37.611463  127.013862
# 4           성북구  석관동미리내도서관       104  37.613522  127.065460
# ..          ...        ...       ...        ...         ...
# 327         노원구    공릉행복도서관     25934  37.622310  127.072753
# 328         노원구  한내지혜의숲도서관     25909  37.621734  127.067641
# 329         노원구    향기나무도서관     25931  37.646499  127.068838
# 330         동작구     까망돌도서관     27737  37.505058  126.960732
# 331         마포구  마포소금나루도서관     10414  37.549567  126.946075
#
# [332 rows x 5 columns]

# %%
df_library_list.to_sql(name='bookInfo', con=engine, if_exists='replace',index=False)
# Out:
# 332

# %%
# !pip uninstall sqlalchemy / !pip install sqlalchemy==1.4.46 => 버전 호환성 이슈로 고생함 하...

# %%
df_bookLoan_1 = pd.read_csv("./FirstHalf_Data/month_1.csv")
df_bookLoan_2 = pd.read_csv("./FirstHalf_Data/month_2.csv")
df_bookLoan_3 = pd.read_csv("./FirstHalf_Data/month_3.csv")
df_bookLoan_4 = pd.read_csv("./FirstHalf_Data/month_4.csv")
df_bookLoan_5 = pd.read_csv("./FirstHalf_Data/month_5.csv")
df_bookLoan_6 = pd.read_csv("./FirstHalf_Data/month_6.csv")

# %%
df_bookLoan_1.to_sql(name='book_Loan_1', con=engine, if_exists='replace',index=False)
df_bookLoan_2.to_sql(name='book_Loan_2', con=engine, if_exists='replace',index=False)
df_bookLoan_3.to_sql(name='book_Loan_3', con=engine, if_exists='replace',index=False)
df_bookLoan_4.to_sql(name='book_Loan_4', con=engine, if_exists='replace',index=False)
df_bookLoan_5.to_sql(name='book_Loan_5', con=engine, if_exists='replace',index=False)
df_bookLoan_6.to_sql(name='book_Loan_6', con=engine, if_exists='replace',index=False)
# Out:
# 2180194

# %%
len(df_bookLoan_1), len(df_bookLoan_2), len(df_bookLoan_3), len(df_bookLoan_4), len(df_bookLoan_5), len(df_bookLoan_6)
# Out:
# (2033091, 2069030, 6941723, 2257840, 4778158, 2180194)

# %%
file_path1 = "./DataSet_row/book_montly/"
file_path2 = os.listdir("./DataSet_row/book_montly/")
file_path3 = os.listdir('./DataSet_row/book_montly/' + file_path2[0])
file_path1 + file_path2[0] + "/" + file_path3[0]
# Out:
# './DataSet_row/book_montly/1/NL_BO_BOOK_PUB_202201-1.csv'

# %%
for name1 in file_path2:
    df_1 = pd.DataFrame()
    print(name1)
    for name2 in os.listdir("./DataSet_row/book_montly/"+name1):
        df_2 = pd.read_csv(file_path1 + name1 + "/" + name2)
        df_2 = df_2[df_2['LBRRY_CD'].isin(target_va)]
        df_1 = pd.concat([df_1, df_2])
    
    df_1.to_csv(name1 + ".csv")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
df = pd.read_csv("./1.csv")
df
# Out:
#         Unnamed: 0       CTRL_NO         AUTHR_NM VLM_NM PBLICTE_YEAR  \
# 0              149     416859491       아리랑도서관 [편]   2019         2019
# 1              150     416859496       아리랑도서관 [편]   2020         2020
# 2              151     416859499       아리랑도서관 [편]   2021         2021
# 3              152     416857067        셀린 시아마 감독    NaN         2021
# 4              153     416857070           유은정 감독    NaN         2021
# ...            ...           ...              ...    ...          ...
# 231892     1170029  100137989415           류승재 지음    NaN         2021
# 231893     1170030  100137989450           김범석 지음    NaN         2021
# 231894     1170031  100137989483  다니엘 콜 저 ;유혜인 옮김    NaN         2021
# 231895     1170032  100137989505  데비 텅 지음 ;최세희 옮김    NaN         2021
# 231896     1170033  100137989528           김민희 지음    NaN         2021
#
#        CL_SMBL_NO BOOK_SMBL_NO  \
# 0            26.3        아298ㅇ
# 1            26.3        아298ㅇ
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CTRL_NO', 'AUTHR_NM', 'VLM_NM', 'PBLICTE_YEAR',
#        'CL_SMBL_NO', 'BOOK_SMBL_NO', 'TITLE_NM', 'LBRRY_CD',
#        'ISBN_THIRTEEN_NO', 'REPRSNT_BOOK_AT', 'REGIST_NO', 'INCME_FLAG_NM',
#        'MANAGE_FLAG_NM', 'MEDIA_FLAG_NM', 'UTILIIZA_LMTT_FLAG_NM',
#        'UTILIIZA_TRGET_FLAG_NM', 'ACP_DATA_NM', 'SGVL_ISBN_NO',
#        'SGVL_ISBN_ADTION_SMBL_NM', 'CL_SMBL_FLAG_NM', 'VLM_SMBL_NM',
#        'DUCACPY_SMBL_NM', 'REGIST_DE', 'ISBN_THIRTEEN_ORGT_NO',
#        'MASTR_LBRRY_CD', 'VLM_EXST_AT', 'SET_ISBN_CHG_AT', 'VLM_ORGT_NM',
#        'TITLE_SBST_NM', 'KDC_NM', 'BOOK_CL_CD', 'BOOK_LC_CD'],
#       dtype='object')

# %%
df[df['LBRRY_CD']==26507]
# Out:
#         Unnamed: 0       CTRL_NO            AUTHR_NM VLM_NM PBLICTE_YEAR  \
# 38428       781980  100136388780              유운성 지음    NaN         2021
# 38429       781981  100136388806              구병모 지음    NaN         2021
# 38430       781982  100136388836              성동혁 지음    NaN         2021
# 38431       781983  100136388861    이언 매큐언 지음;민승남 옮김    NaN         2021
# 38432       781984  100136388883  S. K. 바넷 지음;김효정 옮김    NaN         2021
# ...            ...           ...                 ...    ...          ...
# 231892     1170029  100137989415              류승재 지음    NaN         2021
# 231893     1170030  100137989450              김범석 지음    NaN         2021
# 231894     1170031  100137989483     다니엘 콜 저 ;유혜인 옮김    NaN         2021
# 231895     1170032  100137989505     데비 텅 지음 ;최세희 옮김    NaN         2021
# 231896     1170033  100137989528              김민희 지음    NaN         2021
#
#        CL_SMBL_NO BOOK_SMBL_NO  \
# 38428      688.01        ㅇ588ㅇ
# ...

# %%
df['CL_SMBL_FLAG_NM'].unique()
# Out:
# array([ 1.,  5., nan,  8.,  2.])

# %%
from sqlalchemy import create_engine

user = 'root'
password = 'rkrmfls12!'
host = 'localhost'
port = 3306
database = 'culture_book'

engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}?charset=utf8mb4')

# %%
df_book1 = pd.read_csv("./FirstHalf_book/1.csv")
df_book2 = pd.read_csv("./FirstHalf_book/2.csv")
df_book3 = pd.read_csv("./FirstHalf_book/3.csv")
df_book4 = pd.read_csv("./FirstHalf_book/4.csv")
df_book5 = pd.read_csv("./FirstHalf_book/5.csv")
df_book6 = pd.read_csv("./FirstHalf_book/6.csv")

# %%
total_book = pd.concat([df_book1, df_book2,df_book3,df_book4,df_book5,df_book6])
total_book = total_book.drop(columns=["Unnamed: 0"])
total_book
# Out:
#           CTRL_NO               AUTHR_NM VLM_NM PBLICTE_YEAR CL_SMBL_NO  \
# 0       416859491             아리랑도서관 [편]   2019         2019       26.3
# 1       416859496             아리랑도서관 [편]   2020         2020       26.3
# 2       416859499             아리랑도서관 [편]   2021         2021       26.3
# 3       416857067              셀린 시아마 감독    NaN         2021      688.2
# 4       416857070                 유은정 감독    NaN         2021      688.2
# ...           ...                    ...    ...          ...        ...
# 101483   94231929       by Napoleon Hill    NaN         2021    325.211
# 101484   94231932           by Kate Rose    NaN         2020      848.0
# 101485   94231935       by David Vincent    NaN         2021      848.0
# 101486   94231938  by Brian W. Kernighan    NaN         2021        4.0
# 101487   94231956                 박종석 지음    NaN         2021    327.856
#
#        BOOK_SMBL_NO                                           TITLE_NM  \
# ...

# %%
len(total_book['CTRL_NO'].unique())
# Out:
# 1594312

# %%
df_book1[df_book1['CTRL_NO']==100138525826]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CTRL_NO, AUTHR_NM, VLM_NM, PBLICTE_YEAR, CL_SMBL_NO, BOOK_SMBL_NO, TITLE_NM, LBRRY_CD, ISBN_THIRTEEN_NO, REPRSNT_BOOK_AT, REGIST_NO, INCME_FLAG_NM, MANAGE_FLAG_NM, MEDIA_FLAG_NM, UTILIIZA_LMTT_FLAG_NM, UTILIIZA_TRGET_FLAG_NM, ACP_DATA_NM, SGVL_ISBN_NO, SGVL_ISBN_ADTION_SMBL_NM, CL_SMBL_FLAG_NM, VLM_SMBL_NM, DUCACPY_SMBL_NM, REGIST_DE, ISBN_THIRTEEN_ORGT_NO, MASTR_LBRRY_CD, VLM_EXST_AT, SET_ISBN_CHG_AT, VLM_ORGT_NM, TITLE_SBST_NM, KDC_NM, BOOK_CL_CD, BOOK_LC_CD]
# Index: []
#
# [0 rows x 33 columns]

# %%
df_book2[df_book2['CTRL_NO']==100138525826] # 가설 => 새로 들어온 책만 데이터를 쌓거나, 빌린 책은 소장도서에 제외
# Out:
#       Unnamed: 0       CTRL_NO AUTHR_NM VLM_NM PBLICTE_YEAR CL_SMBL_NO  \
# 7116       63381  100138525826   서한얼 지음    NaN         2012      813.8
#
#      BOOK_SMBL_NO    TITLE_NM  LBRRY_CD  ISBN_THIRTEEN_NO  ...  \
# 7116        ㅅ316ㅂ  바람이 불지 않으면     26507      9.788943e+12  ...
#
#                   REGIST_DE ISBN_THIRTEEN_ORGT_NO MASTR_LBRRY_CD VLM_EXST_AT  \
# 7116  2022-01-19 00:00:00.0          9.788943e+12          26500           N
#
#      SET_ISBN_CHG_AT VLM_ORGT_NM TITLE_SBST_NM KDC_NM BOOK_CL_CD BOOK_LC_CD
# 7116               N         NaN      바람이불지않으면  813.8          J        603
#
# [1 rows x 33 columns]

# %%
df_book1[df_book1['LBRRY_CD']==100]
# Out:
#         Unnamed: 0    CTRL_NO   AUTHR_NM VLM_NM PBLICTE_YEAR CL_SMBL_NO  \
# 12757        67468  416867722  Tony Ross      1         2021      843.0
# 12758        67469  416867726  Tony Ross      2         2021      843.0
# 12759        67470  416867730  Tony Ross      3         2021      843.0
# 12760        67471  416867734  Tony Ross      4         2021      843.0
# 12761        67472  416867738  Tony Ross      5         2021      843.0
# 12762        67473  416867743  Tony Ross      6         2021      843.0
# 12763        67474  416867747  Tony Ross      7         2021      843.0
# 12764        67475  416867751  Tony Ross      8         2021      843.0
# 12765        67476  416867755  Tony Ross      9         2021      843.0
# 12766        67477  416867759  Tony Ross     10         2021      843.0
# 12767        67478  416867763  Tony Ross     11         2021      843.0
# 12768        67479  416867768  Tony Ross     12         2021      843.0
# ...

# %%
total_book.to_sql(name='bookinfo', con=engine, if_exists='replace',index=False)
# Out:
# 1647588

# %%
total_book.to_csv("bookinfo.csv")

# %%
path = "./book/"
os.listdir(path)
# Out:
# ['NL_bo_book_pub_2019-1.csv',
#  'NL_bo_book_pub_2019-19.csv',
#  'NL_bo_book_pub_2019-20.csv',
#  'NL_bo_book_pub_2019-21.csv',
#  'NL_bo_book_pub_2019-22.csv',
#  'NL_bo_book_pub_2019-23.csv',
#  'NL_bo_book_pub_2019-24.csv',
#  'NL_bo_book_pub_2019-25.csv',
#  'NL_bo_book_pub_2019-26.csv',
#  'NL_bo_book_pub_2019-27.csv',
#  'NL_bo_book_pub_2019-28.csv',
#  'NL_bo_book_pub_2019-29.csv']

# %%
df = pd.read_csv("./book/NL_bo_book_pub_2019-1.csv")
for nanm in df.columns:
    print(nanm)
column_list = list(df.columns)
# Out:
# ﻿rec_key
# species_key
# represent_book_yn
# reg_no
# acq_code
# manage_code
# media_code
# use_limit_code
# use_object_code
# author
# vol
# publish_year
# accomp_mat
# ea_isbn
# ea_add_code
# class_no_type
# class_no
# book_code
# vol_code
# copy_code
# reg_date
# title
# lib_code
# isbn13_origin
# isbn13
# master_lib_code
# collect_date
# exist_vol
# set_isbn_change_yn
# vol_origin
# book_seq
# replace_title
# is_wrong_isbn
# is_put_isbn_by_title
# kdc
# insert_date
# separate_shelf_code
# shelf_loc_code
# is_remove
# working_status
# last_shelf_status_change_date
# base_ymd

# %%
df = pd.read_csv("./book/NL_bo_book_pub_2019-1.csv")
for name1 in os.listdir(path):
    try:
        df2 = pd.read_csv(path+name1)
        if len(df2.columns) == 42:
            pass
        else:
            print(name1)
            df2 = df2.reset_index()
            df2 = df2.rename(columns=dict(zip(df2.columns, column_list)))
            df2 = df2[df2['lib_code'].isin(target_va)]
            df = df.append(df2)
    except:
        continue
df.to_csv("./FirstHalf_book/bookinfo4.csv")
# Out:
# NL_bo_book_pub_2019-19.csv
# NL_bo_book_pub_2019-20.csv
# NL_bo_book_pub_2019-23.csv
# NL_bo_book_pub_2019-24.csv
# NL_bo_book_pub_2019-25.csv
# NL_bo_book_pub_2019-26.csv
# NL_bo_book_pub_2019-27.csv

# %%
df
# Out:
#         ﻿rec_key   species_key represent_book_yn        reg_no acq_code  \
# 2266        2987  000000002987               NaN  EM0000002998       구입
# 2267        2907  000000002910               NaN  EM0000002918       구입
# 2268        2936  000000002936               NaN  EM0000002947       구입
# 2269        2967  000000002967               NaN  EM0000002978       구입
# 2270        2816  000000002816               NaN  EM0000002827       구입
# ...          ...           ...               ...           ...      ...
# 1313846   128512        128511                 Y  AEM000070529      NaN
# 1313847   128515        128513                 N  AEM000075568      NaN
# 1313848   128516        128513                 N  AEM000087877      NaN
# 1313849   128518        128517                 Y  AEM000070531      NaN
# 1313850   128520        128519                 Y        AEM000      NaN
#
#         manage_code media_code use_limit_code use_object_code       author  \
# ...

# %%
path = "./book/"
df = pd.DataFrame()
for name1 in os.listdir(path):
    df2 = pd.read_csv(path + name1)
    print(path + name1)
    df2 = df2[df2['LBRRY_CD'].isin(target_va)]
    df = df.append(df2)
df.to_csv("./FirstHalf_book/bookinfo2_20_1.csv")
# Out:
# ./book/NL_BO_BOOK_PUB_202012-1.csv
# ./book/NL_BO_BOOK_PUB_202012-10.csv
# ./book/NL_BO_BOOK_PUB_202012-11.csv
# ./book/NL_BO_BOOK_PUB_202012-12.csv
# ./book/NL_BO_BOOK_PUB_202012-13.csv
# ./book/NL_BO_BOOK_PUB_202012-14.csv
# ./book/NL_BO_BOOK_PUB_202012-15.csv
# ./book/NL_BO_BOOK_PUB_202012-16.csv
# ./book/NL_BO_BOOK_PUB_202012-17.csv
# ./book/NL_BO_BOOK_PUB_202012-18.csv
# ./book/NL_BO_BOOK_PUB_202012-19.csv
# ./book/NL_BO_BOOK_PUB_202012-2.csv
# ./book/NL_BO_BOOK_PUB_202012-20.csv
# ./book/NL_BO_BOOK_PUB_202012-3.csv
# ./book/NL_BO_BOOK_PUB_202012-4.csv
# ./book/NL_BO_BOOK_PUB_202012-5.csv
# ./book/NL_BO_BOOK_PUB_202012-6.csv
# ./book/NL_BO_BOOK_PUB_202012-7.csv
# ./book/NL_BO_BOOK_PUB_202012-8.csv
# ./book/NL_BO_BOOK_PUB_202012-9.csv

# %%
df1 = pd.read_csv("./FirstHalf_book/bookinfo2_20_1.csv")
df2 = pd.read_csv("./FirstHalf_book/bookinfo_22_1.csv")
df3 = pd.read_csv("./FirstHalf_book/bookinfo2_22_2.csv")

bookinfo = pd.concat([df1, df2, df3])

# %%
from sqlalchemy import create_engine

user = 'root'
password = 'rkrmfls12!'
host = 'localhost'
port = 3306
database = 'culture_book'

engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}?charset=utf8mb4')

# %%
bookinfo1 = pd.read_csv("./FirstHalf_book/bookinfo_22_1.csv")
bookinfo1
# Out:
#          Unnamed: 0    CTRL_NO               AUTHR_NM VLM_NM PBLICTE_YEAR  \
# 0                 0  416859491             아리랑도서관 [편]   2019         2019
# 1                 1  416859496             아리랑도서관 [편]   2020         2020
# 2                 2  416859499             아리랑도서관 [편]   2021         2021
# 3                 3  416857067              셀린 시아마 감독    NaN         2021
# 4                 4  416857070                 유은정 감독    NaN         2021
# ...             ...        ...                    ...    ...          ...
# 1647583      101483   94231929       by Napoleon Hill    NaN         2021
# 1647584      101484   94231932           by Kate Rose    NaN         2020
# 1647585      101485   94231935       by David Vincent    NaN         2021
# 1647586      101486   94231938  by Brian W. Kernighan    NaN         2021
# 1647587      101487   94231956                 박종석 지음    NaN         2021
#
#         CL_SMBL_NO BOOK_SMBL_NO  \
# 0             26.3        아298ㅇ
# ...

# %%
bookinfo1 = bookinfo1.drop_duplicates(subset=['CTRL_NO', 'LBRRY_CD'])
# Out:
#          Unnamed: 0    CTRL_NO               AUTHR_NM VLM_NM PBLICTE_YEAR  \
# 0                 0  416859491             아리랑도서관 [편]   2019         2019
# 1                 1  416859496             아리랑도서관 [편]   2020         2020
# 2                 2  416859499             아리랑도서관 [편]   2021         2021
# 3                 3  416857067              셀린 시아마 감독    NaN         2021
# 4                 4  416857070                 유은정 감독    NaN         2021
# ...             ...        ...                    ...    ...          ...
# 1647583      101483   94231929       by Napoleon Hill    NaN         2021
# 1647584      101484   94231932           by Kate Rose    NaN         2020
# 1647585      101485   94231935       by David Vincent    NaN         2021
# 1647586      101486   94231938  by Brian W. Kernighan    NaN         2021
# 1647587      101487   94231956                 박종석 지음    NaN         2021
#
#         CL_SMBL_NO BOOK_SMBL_NO  \
# 0             26.3        아298ㅇ
# ...

# %%
bookinfo1[bookinfo1.duplicated(subset=['CTRL_NO', 'LBRRY_CD'])==True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CTRL_NO, AUTHR_NM, VLM_NM, PBLICTE_YEAR, CL_SMBL_NO, BOOK_SMBL_NO, TITLE_NM, LBRRY_CD, ISBN_THIRTEEN_NO, REPRSNT_BOOK_AT, REGIST_NO, INCME_FLAG_NM, MANAGE_FLAG_NM, MEDIA_FLAG_NM, UTILIIZA_LMTT_FLAG_NM, UTILIIZA_TRGET_FLAG_NM, ACP_DATA_NM, SGVL_ISBN_NO, SGVL_ISBN_ADTION_SMBL_NM, CL_SMBL_FLAG_NM, VLM_SMBL_NM, DUCACPY_SMBL_NM, REGIST_DE, ISBN_THIRTEEN_ORGT_NO, MASTR_LBRRY_CD, VLM_EXST_AT, SET_ISBN_CHG_AT, VLM_ORGT_NM, TITLE_SBST_NM, KDC_NM, BOOK_CL_CD, BOOK_LC_CD]
# Index: []
#
# [0 rows x 33 columns]

# %%
bookinfo1 = pd.read_csv("./FirstHalf_book/bookinfo2_20_1.csv")
bookinfo1 = bookinfo1[['CTRL_NO', 'LBRRY_CD','TITLE_NM',  'KDC_NM', 'ISBN_THIRTEEN_ORGT_NO', 'CL_SMBL_NO']]
bookinfo1.to_sql(name='bookinfo1', con=engine, if_exists='replace',index=False)

# %%
bookinfo2 = pd.read_csv("./FirstHalf_book/bookinfo_22_1.csv")
bookinfo2 = bookinfo2.drop_duplicates(subset=['CTRL_NO', 'LBRRY_CD'])
bookinfo2 = bookinfo2[['CTRL_NO', 'LBRRY_CD','TITLE_NM',  'KDC_NM', 'ISBN_THIRTEEN_ORGT_NO', 'CL_SMBL_NO']]
bookinfo2.to_sql(name='bookinfo2', con=engine, if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 bookinfo2 = bookinfo2.drop_duplicates(subset=['CTRL_NO', 'LBRRY_CD'])
#       3 bookinfo2 = bookinfo2[['CTRL_NO', 'LBRRY_CD','TITLE_NM',  'KDC_NM', 'ISBN_THIRTEEN_ORGT_NO', 'CL_SMBL_NO']]
# ----> 4 bookinfo2.to_sql(name='bookinfo2', con=engine, if_exists='replace',index=False)
#
# NameError: name 'engine' is not defined

# %%
bookinfo3 = pd.read_csv("./FirstHalf_book/bookinfo2_22_2.csv")
bookinfo3 = bookinfo3.drop_duplicates(subset=['CTRL_NO', 'LBRRY_CD'])
bookinfo3 = bookinfo3[['CTRL_NO', 'LBRRY_CD','TITLE_NM',  'KDC_NM', 'ISBN_THIRTEEN_ORGT_NO', 'CL_SMBL_NO']]
bookinfo3.to_sql(name='bookinfo3', con=engine, if_exists='replace',index=False)

# %%
bookinfo1 = pd.read_csv("./FirstHalf_book/final_bookinfo.csv")

bookinfo1.to_csv("./final_book.csv", encoding='utf-8')

# %%
bookinfo1.to_csv("./final_book.csv", encoding='UTF-8')

# %%
len(bookinfo1)
# Out:
# 24664637

# %%
bookinfo1.iloc[0:14000000, :].to_csv("./FirstHalf_book/book1.csv")

# %%
bookinfo1.iloc[14000001:, :].to_csv("./FirstHalf_book/book2.csv")

# %%
df1 = pd.read_csv("./FirstHalf_book/book1.csv")
df1.to_sql(name='book1', con=engine, if_exists='replace',index=False)

# %%
df1 = pd.read_csv("./FirstHalf_book/book2.csv")
df1.to_sql(name='book2', con=engine, if_exists='replace',index=False)

# %%
df = pd.read_csv("./FirstHalf_book/df_7.csv", index_col=False)
df = df.drop(columns="Unnamed: 0")
df.columns
# Out:
# Index(['CTRL_NO', 'LBRRY_CD', 'TITLE_NM', 'KDC_NM', 'ISBN_THIRTEEN_ORGT_NO',
#        'CL_SMBL_NO'],
#       dtype='object')

# %%
os.listdir("./FirstHalf_book/")
# Out:
# ['df.csv',
#  'df_0.csv',
#  'df_1.csv',
#  'df_2.csv',
#  'df_3.csv',
#  'df_4.csv',
#  'df_5.csv',
#  'df_6.csv',
#  'df_7.csv']

# %%
list_file = os.listdir("./FirstHalf_book/")

for num in range(len(list_file)):
    df = pd.read_csv("./FirstHalf_book/" + list_file[num])
    df = df.drop(columns="Unnamed: 0")
    df.to_sql(name=f'book_info{num}', con=engine, if_exists='append',index=False)
    del df

# %% [markdown]
# - mysql에서 kDC카테고리별로 확인 결과 문화책의 비중이 모든 도서관에서 압도적으로 높기에 프로젝트의 방향성을 바꿈
# - 도서관 근처의 인구통계 데이터, 도서 사용 실태조사 데이터 등을 수집 및 전처리와 분석을 하고, 스마트도서관의 이용률과 분석해서 국립도서관에서 분석한 요인을 종속변수로, 스마트도서관 이용륭을 독립변수로 설정해 요인분석으로 진행함

# %%
df = pd.read_excel("./DataSet_row/(원데이터)도서관 이용실태조사 DATA.xlsx")
df
# Out:
#         지역  성별     연령대     학업수준    독서 방법           구매 방식
# 0      종로구  여성  70세 이상  고등학교 졸업
# 1      종로구  여성     20대   대학교 졸업        집        도서관에서 빌림
# 2      종로구  여성     20대   전문대 졸업
# 3      종로구  여성     10대   중학교 졸업        집        도서관에서 빌림
# 4      종로구  여성     10대   중학교 졸업        집        도서관에서 빌림
# ...    ...  ..     ...      ...      ...             ...
# 3059   용산구  여성     50대   전문대 졸업        집        도서관에서 빌림
# 3060   중랑구  남성     60대  고등학교 졸업       카페    서점 및 카페에서 읽음
# 3061   용산구  여성     20대   전문대 졸업        집        도서관에서 빌림
# 3062  서대문구  여성     20대   대학교 졸업        집         지인에게 빌림
# 3063   중랑구  남성     20대  고등학교 졸업  직장 및 학교  인터넷 등 전자책으로 읽음
#
# [3064 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3064 entries, 0 to 3063
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      3064 non-null   object
#  1   성별      3064 non-null   object
#  2   연령대     3064 non-null   object
#  3   학업수준    3064 non-null   object
#  4   독서 방법   3064 non-null   object
#  5   구매 방식   3064 non-null   object
# dtypes: object(6)
# memory usage: 143.8+ KB

# %%
for name in df.columns:
    print(name, df[name].unique())
# Out:
# 지역 ['종로구' '중구' '용산구' '성동구' '광진구' '동대문구' '중랑구' '성북구' '강북구' '도봉구' '노원구' '은평구'
#  '서대문구' '마포구' '양천구' '강서구' '구로구' '금천구' '영등포구' '동작구' '관악구' '서초구' '강남구' '송파구'
#  '강동구']
# 성별 ['여성' '남성']
# 연령대 ['70세 이상' '20대' '10대' '50대' '40대' '30대' '60대']
# 학업수준 ['고등학교 졸업' '대학교 졸업' '전문대 졸업' '중학교 졸업' '대학교 중퇴' '4년제 대학교 졸업' '초등학교 졸업 이하']
# 독서 방법 [' ' '집' '장소를 가리지 않음' '직장 및 학교' '서점' '이동중' '카페' '직장 및 학교이동중' '직장 및 학교집'
#  '직장 및 학교직장 및 학교']
# 구매 방식 [' ' '도서관에서 빌림' '구매 ' '지인에게 빌림' '인터넷 등 전자책으로 읽음' '서점 및 카페에서 읽음'
#  '지인에게 빌림구매 ']

# %%
for name in df.columns:
    df[name] = df[name].replace(" ", "")

# %%
for name in df.columns:
    print(name, df[name].unique())
# Out:
# 지역 ['종로구' '중구' '용산구' '성동구' '광진구' '동대문구' '중랑구' '성북구' '강북구' '도봉구' '노원구' '은평구'
#  '서대문구' '마포구' '양천구' '강서구' '구로구' '금천구' '영등포구' '동작구' '관악구' '서초구' '강남구' '송파구'
#  '강동구']
# 성별 ['여성' '남성']
# 연령대 ['70세 이상' '20대' '10대' '50대' '40대' '30대' '60대']
# 학업수준 ['고등학교 졸업' '대학교 졸업' '전문대 졸업' '중학교 졸업' '대학교 중퇴' '4년제 대학교 졸업' '초등학교 졸업 이하']
# 독서 방법 ['' '집' '장소를 가리지 않음' '직장 및 학교' '서점' '이동중' '카페' '직장 및 학교이동중' '직장 및 학교집'
#  '직장 및 학교직장 및 학교']
# 구매 방식 ['' '도서관에서 빌림' '구매 ' '지인에게 빌림' '인터넷 등 전자책으로 읽음' '서점 및 카페에서 읽음'
#  '지인에게 빌림구매 ']

# %%
df_gu = df.set_index("지역")
df_gu
# Out:
#       성별     연령대     학업수준    독서 방법           구매 방식
# 지역
# 종로구   여성  70세 이상  고등학교 졸업
# 종로구   여성     20대   대학교 졸업        집        도서관에서 빌림
# 종로구   여성     20대   전문대 졸업
# 종로구   여성     10대   중학교 졸업        집        도서관에서 빌림
# 종로구   여성     10대   중학교 졸업        집        도서관에서 빌림
# ...   ..     ...      ...      ...             ...
# 용산구   여성     50대   전문대 졸업        집        도서관에서 빌림
# 중랑구   남성     60대  고등학교 졸업       카페    서점 및 카페에서 읽음
# 용산구   여성     20대   전문대 졸업        집        도서관에서 빌림
# 서대문구  여성     20대   대학교 졸업        집         지인에게 빌림
# 중랑구   남성     20대  고등학교 졸업  직장 및 학교  인터넷 등 전자책으로 읽음
#
# [3064 rows x 5 columns]

# %%
df_total_index = df.set_index(['지역', '성별', '연령대'])
df_total_index
# Out:
#                    학업수준    독서 방법           구매 방식
# 지역   성별 연령대
# 종로구  여성 70세 이상  고등학교 졸업
#         20대      대학교 졸업        집        도서관에서 빌림
#         20대      전문대 졸업
#         10대      중학교 졸업        집        도서관에서 빌림
#         10대      중학교 졸업        집        도서관에서 빌림
# ...                 ...      ...             ...
# 용산구  여성 50대      전문대 졸업        집        도서관에서 빌림
# 중랑구  남성 60대     고등학교 졸업       카페    서점 및 카페에서 읽음
# 용산구  여성 20대      전문대 졸업        집        도서관에서 빌림
# 서대문구 여성 20대      대학교 졸업        집         지인에게 빌림
# 중랑구  남성 20대     고등학교 졸업  직장 및 학교  인터넷 등 전자책으로 읽음
#
# [3064 rows x 3 columns]

# %%
df_gu = pd.get_dummies(df_gu)
df_gu
# Out:
#       성별_남성  성별_여성  연령대_10대  연령대_20대  연령대_30대  연령대_40대  연령대_50대  연령대_60대  \
# 지역
# 종로구       0      1        0        0        0        0        0        0
# 종로구       0      1        0        1        0        0        0        0
# 종로구       0      1        0        1        0        0        0        0
# 종로구       0      1        1        0        0        0        0        0
# 종로구       0      1        1        0        0        0        0        0
# ...     ...    ...      ...      ...      ...      ...      ...      ...
# 용산구       0      1        0        0        0        0        1        0
# 중랑구       1      0        0        0        0        0        0        1
# 용산구       0      1        0        1        0        0        0        0
# 서대문구      0      1        0        1        0        0        0        0
# 중랑구       1      0        0        1        0        0        0        0
#
#       연령대_70세 이상  학업수준_4년제 대학교 졸업  ...  독서 방법_직장 및 학교집  독서 방법_집  독서 방법_카페  \
# ...

# %%
df_gu = df_gu.reset_index().groupby("지역").sum()
df_gu
# Out:
#       성별_남성  성별_여성  연령대_10대  연령대_20대  연령대_30대  연령대_40대  연령대_50대  연령대_60대  \
# 지역
# 강남구      60     64       20       21       20       20       22       19
# 강동구      60     63       21       20       20       22       21       14
# 강북구      64     61       20       21       20       20       21       16
# 강서구      60     61       20       22       20       20       19       12
# 관악구      59     62       19       21       20       19       23       18
# 광진구      59     64       23       20       20       19       20       21
# 구로구      60     62       19       22       18       22       21       15
# 금천구      63     61       18       20       22       20       23       16
# 노원구      60     60       20       20       20       19       20       12
# 도봉구      66     64       22       21       21       20       24       21
# 동대문구     60     63       19       19       20       20       21       14
# 동작구      60     60       19       18       20       21       19       15
# ...

# %%
df_total_index = pd.get_dummies(df_total_index)
df_total_index
# Out:
#                 학업수준_4년제 대학교 졸업  학업수준_고등학교 졸업  학업수준_대학교 졸업  학업수준_대학교 중퇴  \
# 지역   성별 연령대
# 종로구  여성 70세 이상                0             1            0            0
#         20대                   0             0            1            0
#         20대                   0             0            0            0
#         10대                   0             0            0            0
#         10대                   0             0            0            0
# ...                         ...           ...          ...          ...
# 용산구  여성 50대                   0             0            0            0
# 중랑구  남성 60대                   0             1            0            0
# 용산구  여성 20대                   0             0            0            0
# 서대문구 여성 20대                   0             0            1            0
# 중랑구  남성 20대                   0             1            0            0
#
#                 학업수준_전문대 졸업  학업수준_중학교 졸업  학업수준_초등학교 졸업 이하  독서 방법_  독서 방법_서점  \
# ...

# %%
df_total_index = df_total_index.reset_index().groupby(["지역", "성별", "연령대"]).sum()
df_total_index
# Out:
#                학업수준_4년제 대학교 졸업  학업수준_고등학교 졸업  학업수준_대학교 졸업  학업수준_대학교 중퇴  \
# 지역  성별 연령대
# 강남구 남성 10대                   0             0            0            0
#        20대                   2             5            2            0
#        30대                   3             0            6            0
#        40대                   3             0            7            0
#        50대                   1             7            1            0
# ...                        ...           ...          ...          ...
# 중랑구 여성 30대                   2             5            0            0
#        40대                   1             2            2            0
#        50대                   1             6            0            0
#        60대                   0             5            0            0
#        70세 이상                0             0            0            0
#
#                학업수준_전문대 졸업  학업수준_중학교 졸업  학업수준_초등학교 졸업 이하  독서 방법_  독서 방법_서점  \
# 지역  성별 연령대
# ...

# %%
df_gu['성별_남성'].sum()
# Out:
# 1525
